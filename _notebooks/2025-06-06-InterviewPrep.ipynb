# %% [markdown]
# ---
# comments: true
# layout: post
# title: Interview Prep
# permalink: /interviewprep
# type: hacks
# ---

# %% [markdown]
# ## Preview of LinkedIn profile
#
# - [My LinkedIn](https://www.linkedin.com/in/eshaan-kumar-sd/)
#
# ## Key Interests and Coding intersection
#
# - MechE at UW
# - Coding background can help me combine software with hardware
# - Robotics opportunities by coding physical objects
#
# ## Projects and Teamwork
#
# - Agile methodology with scrum leader for my feature
# - My role as a tester and notifying department developers to fix issues in their features
# - Show collaboration with my testing group and developer groups across the class on Slack
#
# ## Full Stack Experience
#
# - CSP projects: chat, stocksense
#
# ## ML Experience
#
# - CSP project: house price predictor
# - SDSC project (still developing): EcoSort
#
# ## GitHub Project and Profile
#
# - [My GitHub](https://github.com/eshaank1)
#
# ## Project Showcase
#
# - Presented at NATM at DNHS
# - Led live demos for groups of other students and parents
# - Explained our development process and how our full stack project is run
#
# ## NFT
#
# - Teaching skills as a tennis instructor + experience in coding so I can create a good educational CS program for students to learn coding through Open Coding Society
# - Lots of coding experience outside CSP/CSA/Open Coding Society, such as 2 internships at SDSC

# %% [markdown]
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Roboto');
# h1{ text-align: center; font-size: 50px; color: #0352fc; font-family: 'Roboto', serif;}
# h2{ text-align: left; font-size: 18px; color: #0352fc;}
# body{ text-align: left; font-size: 15px; font-family: 'Roboto', serif; background: black; }
# </style>
